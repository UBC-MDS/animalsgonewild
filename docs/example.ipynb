# %% [markdown]
# # Example usage
#
# To use `animalsgonewild` in a project:

# %%
import animalsgonewild

print(animalsgonewild.__version__)
# Out:
# 0.1.0

# %% [markdown]
# To use the `animalClassifier` function:

# %%
from animalsgonewild.animalsgonewild import animalClassifier

text = "any text you wish to use saved as a string"

animalClassifier(text)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\kylem\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\kylem\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# 'Whale'

# %% [markdown]
# To use the `animalType` function:

# %%
from animalsgonewild.animalsgonewild import animalType

text = "any text you wish to use saved as a string"
species = animalClassifier(text)

animalType(species, text)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=300x250 at 0x17D2AED5070>

# %% [markdown]
# To use the `textTransformer` function:

# %%
from animalsgonewild.animalsgonewild import textTransformer

text = "any text you wish to use saved as a string"

textTransformer(text)
# Out:
# 'any Whale you Whale to Whale saved as Whale Whale'

# %% [markdown]
# To use the `wordCloud` function:

# %%
from animalsgonewild.animalsgonewild import wordCloud

link = 'https://www.britannica.com/place/Japan'

wordCloud(link)
# Out:
# 'whale'
